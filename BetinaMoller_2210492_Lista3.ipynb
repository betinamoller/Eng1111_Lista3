# %% [markdown]
# 1-Salve a base de dados escolhida no seu drive e importe para um notebook do Colab, criando um Dataframe

# %%
import pandas as pd
from google.colab import drive
drive.mount('/drive')
dados=pd.read_csv("/drive/MyDrive/class_german_credit.csv")
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %% [markdown]
# 2-Inspecione as colunas do conjunto de dados (Nome das colunas e tipo de dados)

# %%
print(dados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   object
#  4   Saving accounts   817 non-null    object
#  5   Checking account  606 non-null    object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
#  9   Risk              1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.2+ KB
# None

# %% [markdown]
# 3-Escolha uma coluna com valores numéricos e apague todas as linhas que possuam valor nulo

# %%
dados["Credit amount"]
nova=dados.dropna()
display(nova)

# %% [markdown]
# 4-Calcule a média desta mesma coluna

# %%
media=dados["Credit amount"].mean()
print(media)
# Out:
# 3271.258

# %% [markdown]
# 5-Escolha um critério para eliminar as linhas que possuam valores muito distantes da média e crie um novo Dataframe.

# %%
dados=pd.read_csv("/drive/MyDrive/class_german_credit.csv")
media=dados["Credit amount"].mean()

# %% [markdown]
# 6-Crie um novo Dataframe que contenha apenas 5 colunas do conjunto anterior.

# %%
col_1=dados['Age']
col_2=dados['Job']
col_3=dados['Saving accounts']
col_4=dados['Housing']
col_5=dados['Duration']

res=pd.concat([col_1,col_2,col_3,col_4,col_5],axis=1)

display(res)
# Out:
#      Age  Job Saving accounts Housing  Duration
# 0     67    2             NaN     own         6
# 1     22    2          little     own        48
# 2     49    1          little     own        12
# 3     45    2          little    free        42
# 4     53    2          little    free        24
# ..   ...  ...             ...     ...       ...
# 995   31    1          little     own        12
# 996   40    3          little     own        30
# 997   38    2          little     own        12
# 998   23    2          little    free        45
# 999   27    2        moderate     own        45
#
# [1000 rows x 5 columns]

# %% [markdown]
# 7-Escolha duas colunas numéricas e crie uma nova coluna que siga a regra: (Coluna A - Coluna B)*número aleatório (entre 0 e 1).

# %%
import random
dados.insert(1,'novaColuna',(dados['Duration']-dados['Job']*random.randint(0,1)))

#fiquei confusa em como selecionar o numero aleatorio entre 0 e 1 porque a funcao randint na verdade so funciona com numeros inteiros

# %% [markdown]
# 8-Embaralhe aleatoriamente o dataframe (índices e valores).

# %%
import numpy as np
dados2=dados.reindex(np.random.permutation(dados.index))
display(dados2)
# Out:
#      Age  novaColuna     Sex  Job Housing Saving accounts Checking account  \
# 335   44           3    male    3    rent          little           little
# 869   24          10  female    2    rent          little           little
# 883   65          18  female    0     own          little              NaN
# 46    39          34    male    2     own      quite rich              NaN
# 667   27          46  female    2     own          little              NaN
# ..   ...         ...     ...  ...     ...             ...              ...
# 196   28           4  female    2     own          little              NaN
# 849   57          11    male    1     own          little           little
# 716   40          28    male    2     own             NaN              NaN
# 844   47          16    male    2     own          little              NaN
# 901   44          18    male    2     own             NaN              NaN
#
#      Credit amount  Duration              Purpose  Risk
# 335           3384         6  furniture/equipment   bad
# 869            652        12  furniture/equipment  good
# 883           1098        18             radio/TV  good
# 46            2299        36             radio/TV  good
# 667           3609        48             business  good
# ..             ...       ...                  ...   ...
# 196           1382         6             radio/TV  good
# 849            709        12             radio/TV   bad
# 716           3077        30             radio/TV  good
# 844           3422        18  furniture/equipment  good
# 901           3485        20                  car  good
#
# [1000 rows x 11 columns]

# %% [markdown]
# 9-Ordene o Dataframe seguindo um critério definido por você (Explique o critério)

# %%
dados=pd.read_csv("/drive/MyDrive/class_german_credit.csv")
dado=dados.sort_values(by='Age',ascending=True)
#ordena pela idade, do mais novo até o mais velho
#nesse caso da para ver se a idade tem alguma relacao com os outros aspectos
display(dado)
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 391   19  female    1    rent            rich         moderate            983
# 633   19  female    2    rent          little              NaN           1980
# 513   20    male    2    rent          little         moderate            585
# 155   20  female    2    rent          little           little           1282
# 410   20  female    2     own          little         moderate           1967
# ..   ...     ...  ...     ...             ...              ...            ...
# 606   74    male    3     own          little              NaN           4526
# 186   74  female    3    free          little         moderate           5129
# 430   74    male    1     own          little              NaN           3448
# 330   75    male    3    free          little           little           6615
# 536   75  female    3     own             NaN           little           1374
#
#      Duration              Purpose  Risk
# 391        12  furniture/equipment  good
# 633         9  furniture/equipment   bad
# 513        12             radio/TV  good
# 155        12  furniture/equipment   bad
# 410        24             radio/TV  good
# ..        ...                  ...   ...
# 606        24             business  good
# 186         9                  car   bad
# 430         5             business  good
# 330        24                  car  good
# 536         6                  car  good
#
# [1000 rows x 10 columns]

# %% [markdown]
# 10-Escolha uma coluna numérica e um coluna com strings e utilize a função Groupby para mostrar os totais da  coluna.

# %%
grp=dados.groupby('Job')[['Saving accounts']].count()
display(grp)
# Out:
#      Saving accounts
# Job
# 0                 17
# 1                171
# 2                510
# 3                119

# %% [markdown]
# 11-Utilize a função MAPS para fazer algum tipo de substituição no Dataframe (explique)

# %%
dados['Housing status']=dados['Housing'].map(
    {'rent':1,'own':2,'free':3})
#associei o tipo de moradia da pessoa a numeros, assim é possivel diferenciar quem mora em apt alugado, proprio
display(dados)
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male    2     own             NaN           little           1169
# 1     22  female    2     own          little         moderate           5951
# 2     49    male    1     own          little              NaN           2096
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
#      Duration              Purpose  Risk Housing_status  Housing status
# 0           6             radio/TV  good            NaN               2
# 1          48             radio/TV   bad            NaN               2
# 2          12            education  good            NaN               2
# 3          42  furniture/equipment  good            NaN               3
# 4          24                  car   bad            NaN               3
# ..        ...                  ...   ...            ...             ...
# 995        12  furniture/equipment  good            NaN               2
# 996        30                  car  good            NaN               2
# 997        12             radio/TV  good            NaN               2
# 998        45             radio/TV   bad            NaN               3
# 999        45                  car  good            NaN               2
#
# [1000 rows x 12 columns]

# %% [markdown]
# 12-Exporte o último Dataframe para um arquivo CSV e salve no seu drive

# %%
dados.to_csv("/drive/MyDrive/novo_class_german_credit.csv")

# %% [markdown]
# 13-Exporte o mesmo Dataframe para um arquivo JSON e salve no seu drive

# %%
dados.to_json("/drive/MyDrive/novo2_class_german_credit.csv")
